# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('usd_toman_history.csv')
df = df.set_index('date_pr')

# %%
df['presidency'] = None
df.loc['1360/07/18','presidency'] = 'Khamenei'
df.loc['1368/05/25','presidency'] = 'Rafsanjani'
df.loc['1376/05/12','presidency'] = 'Khatami'
df.loc['1384/05/12','presidency'] = 'AhmadiNezhad'
df.loc['1392/05/12','presidency'] = 'Rohani'
df.loc['1400/05/12','presidency'] = 'Raeesi'

# %%
df = df.reset_index()
df = df.set_index('date_gr')

# %%
df
# Out:
#                         date_pr      source  price_avg presidency
# date_gr
# 1981/09/29 00:00:00  1360/07/07  bourseview      270.0       None
# 1981/09/30 00:00:00  1360/07/08  bourseview      270.0       None
# 1981/10/01 00:00:00  1360/07/09  bourseview      270.0       None
# 1981/10/03 00:00:00  1360/07/11  bourseview      270.0       None
# 1981/10/04 00:00:00  1360/07/12  bourseview      270.0       None
# ...                         ...         ...        ...        ...
# 2023/02/21 00:00:00  1401/12/02     BonBast   497500.0       None
# 2023/02/22 00:00:00  1401/12/03     BonBast   512500.0       None
# 2023/02/23 00:00:00  1401/12/04     BonBast   526000.0       None
# 2023/02/24 00:00:00  1401/12/05     BonBast   539500.0       None
# 2023/02/25 00:00:00  1401/12/06     BonBast   574500.0       None
#
# [12446 rows x 4 columns]

# %%
df['US_presidency'] = None
df.loc['1981/09/29 00:00:00','US_presidency'] = 'Carter'
df.loc['1989/02/20 00:00:00','US_presidency'] = 'Bush'
df.loc['1993/01/20 00:00:00','US_presidency'] = 'Clinton'
df.loc['2001/01/20 00:00:00','US_presidency'] = 'Bush'
df.loc['2009/01/20 00:00:00','US_presidency'] = 'Obama'
df.loc['2017/01/19 00:00:00','US_presidency'] = 'Trump'
df.loc['2021/01/20 00:00:00','US_presidency'] = 'Biden'

# %%
df
# Out:
#                         date_pr      source  price_avg presidency  \
# date_gr
# 1981/09/29 00:00:00  1360/07/07  bourseview      270.0       None
# 1981/09/30 00:00:00  1360/07/08  bourseview      270.0       None
# 1981/10/01 00:00:00  1360/07/09  bourseview      270.0       None
# 1981/10/03 00:00:00  1360/07/11  bourseview      270.0       None
# 1981/10/04 00:00:00  1360/07/12  bourseview      270.0       None
# ...                         ...         ...        ...        ...
# 2023/02/21 00:00:00  1401/12/02     BonBast   497500.0       None
# 2023/02/22 00:00:00  1401/12/03     BonBast   512500.0       None
# 2023/02/23 00:00:00  1401/12/04     BonBast   526000.0       None
# 2023/02/24 00:00:00  1401/12/05     BonBast   539500.0       None
# 2023/02/25 00:00:00  1401/12/06     BonBast   574500.0       None
#
#                     US_presidency
# date_gr
# 1981/09/29 00:00:00        Carter
# 1981/09/30 00:00:00          None
# 1981/10/01 00:00:00          None
# 1981/10/03 00:00:00          None
# 1981/10/04 00:00:00          None
# ...                           ...
# 2023/02/21 00:00:00          None
# 2023/02/22 00:00:00          None
# 2023/02/23 00:00:00          None
# 2023/02/24 00:00:00          None
# 2023/02/25 00:00:00          None
#
# [12446 rows x 5 columns]

# %%
df = df.reset_index()

# %%
df
# Out:
#                    date_gr     date_pr      source  price_avg presidency  \
# 0      1981/09/29 00:00:00  1360/07/07  bourseview      270.0       None
# 1      1981/09/30 00:00:00  1360/07/08  bourseview      270.0       None
# 2      1981/10/01 00:00:00  1360/07/09  bourseview      270.0       None
# 3      1981/10/03 00:00:00  1360/07/11  bourseview      270.0       None
# 4      1981/10/04 00:00:00  1360/07/12  bourseview      270.0       None
# ...                    ...         ...         ...        ...        ...
# 12441  2023/02/21 00:00:00  1401/12/02     BonBast   497500.0       None
# 12442  2023/02/22 00:00:00  1401/12/03     BonBast   512500.0       None
# 12443  2023/02/23 00:00:00  1401/12/04     BonBast   526000.0       None
# 12444  2023/02/24 00:00:00  1401/12/05     BonBast   539500.0       None
# 12445  2023/02/25 00:00:00  1401/12/06     BonBast   574500.0       None
#
#       US_presidency
# 0            Carter
# 1              None
# 2              None
# 3              None
# 4              None
# ...             ...
# 12441          None
# 12442          None
# 12443          None
# 12444          None
# 12445          None
#
# [12446 rows x 6 columns]

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,1,1)
y = df.price_avg
x = np.arange(len(y))
dates = df.date_pr
plt.plot(x,y)

for i, row in df[['presidency']].dropna().iterrows():
    plt.axvline(x=i,color='gray')
    plt.annotate(text = row.presidency, xy = (i+20,5.3))

plt.xticks([],[],rotation=90)
plt.title('Log of Dollar value to Iran Rial during Islamic Republic')

plt.subplot(2,1,2)
y = df.price_avg
x = np.arange(len(y))
dates = df.date_pr
plt.plot(x,y)
for i, row in df[['US_presidency']].dropna().iterrows():
    plt.axvline(x=i,color='purple')
    plt.annotate(text = row.US_presidency, xy = (i+20,13))


plt.xticks(x[::-365],dates[::-365],rotation=90)
plt.tight_layout()
plt.savefig('total_log.png',dpi=900)
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,1,1)
y = df.price_avg
x = np.arange(len(y))
dates = df.date_pr
plt.plot(x,np.log(y))

for i, row in df[['presidency']].dropna().iterrows():
    plt.axvline(x=i,color='gray')
    plt.annotate(text = row.presidency, xy = (i+20,5.3))

plt.xticks([],[],rotation=90)
plt.title('Log of Dollar value to Iran Rial during Islamic Republic')

plt.subplot(2,1,2)
y = df.price_avg
x = np.arange(len(y))
dates = df.date_pr
plt.plot(x,np.log(y))
for i, row in df[['US_presidency']].dropna().iterrows():
    plt.axvline(x=i,color='purple')
    plt.annotate(text = row.US_presidency, xy = (i+20,13))


plt.xticks(x[::-365],dates[::-365],rotation=90)
plt.tight_layout()
plt.savefig('total_log.png',dpi=900)
plt.show()

# %%
def curvefit(x,y):
    A = np.vstack([x**i for i in range(2)]).T
    p = np.linalg.lstsq(A, y, rcond=None)[0]
    
    return p

# %%
summary_df = pd.DataFrame(index = ['Khamenei','Rafsanjani', 'Khatami','AhmadiNezhad','Rohani','Raeesi'], 
                      columns = ['Average Daily Growth Percentage'])

# %%
wdf = (df.loc[
    df[df.presidency == 'Khamenei'].index[0]:
    df[df.presidency == 'Rafsanjani'].index[0]-1]
      ).copy()
plt.figure(figsize=(12,4))
y = wdf.price_avg
x = np.arange(len(y))
p = curvefit(x,y)
dates = wdf.date_pr
plt.plot(x,y)
plt.xticks(x[::-365],dates[::-365])
plt.title('Khamenei')

av_d_g = wdf.price_avg.rolling(2).apply(lambda wsr: (wsr.iloc[1]-wsr.iloc[0])/wsr.iloc[0]).mean()*100
summary_df.loc['Khamenei','Average Daily Growth Percentage'] = av_d_g

plt.annotate(f'Average Daily Growth Percentage:{av_d_g:.3f}',xy=(20,1000))
plt.savefig('khamenie.png',dpi=900)
plt.show()

# %%
wdf = (df.loc[
    df[df.presidency == 'Rafsanjani'].index[0]:
    df[df.presidency == 'Khatami'].index[0]-1]
      ).copy()
plt.figure(figsize=(12,4))
y = wdf.price_avg
x = np.arange(len(y))
p = curvefit(x,y)
dates = wdf.date_pr
plt.plot(x,y)
plt.xticks(x[::-365],dates[::-365])
plt.title('Rafsanjani')
av_d_g = wdf.price_avg.rolling(2).apply(lambda wsr: (wsr.iloc[1]-wsr.iloc[0])/wsr.iloc[0]).mean()*100
summary_df.loc['Rafsanjani','Average Daily Growth Percentage'] = av_d_g
plt.annotate(f'Average Daily Growth Percentage:{av_d_g:.3f}',xy=(20,4000))
plt.savefig('Rafsanjani.png',dpi=900)
plt.show()

# %%
wdf = (df.loc[
    df[df.presidency == 'Khatami'].index[0]:
    df[df.presidency == 'AhmadiNezhad'].index[0]-1]
      ).copy()
plt.figure(figsize=(12,4))
y = wdf.price_avg
x = np.arange(len(y))
p = curvefit(x,y)
dates = wdf.date_pr
plt.plot(x,y)
plt.xticks(x[::-365],dates[::-365])
plt.title('Khatami')
av_d_g = wdf.price_avg.rolling(2).apply(lambda wsr: (wsr.iloc[1]-wsr.iloc[0])/wsr.iloc[0]).mean()*100
summary_df.loc['Khatami','Average Daily Growth Percentage'] = av_d_g
plt.annotate(f'Average Daily Growth Percentage:{av_d_g:.3f}',xy=(550,6000))
plt.savefig('Khatami.png',dpi=900)
plt.show()

# %%
wdf = (df.loc[
    df[df.presidency == 'AhmadiNezhad'].index[0]:
    df[df.presidency == 'Rohani'].index[0]-1]
      ).copy()
plt.figure(figsize=(12,4))
y = wdf.price_avg
x = np.arange(len(y))
p = curvefit(x,y)
dates = wdf.date_pr
plt.plot(x,y)
plt.xticks(x[::-365],dates[::-365])
plt.title('AhmadiNezhad')

av_d_g = wdf.price_avg.rolling(2).apply(lambda wsr: (wsr.iloc[1]-wsr.iloc[0])/wsr.iloc[0]).mean()*100
summary_df.loc['AhmadiNezhad','Average Daily Growth Percentage'] = av_d_g
plt.annotate(f'Average Daily Growth Percentage:{av_d_g:.3f}',xy=(20,30000))
plt.savefig('AhmadiNezhad.png',dpi=900)
plt.show()

# %%
wdf = (df.loc[
    df[df.presidency == 'Rohani'].index[0]:
    df[df.presidency == 'Raeesi'].index[0]-1]
      ).copy()
plt.figure(figsize=(12,4))
y = wdf.price_avg
x = np.arange(len(y))
p = curvefit(x,y)
dates = wdf.date_pr
plt.plot(x,y)
plt.xticks(x[::-365],dates[::-365])
plt.title('Rohani')

av_d_g = wdf.price_avg.rolling(2).apply(lambda wsr: (wsr.iloc[1]-wsr.iloc[0])/wsr.iloc[0]).mean()*100
summary_df.loc['Rohani','Average Daily Growth Percentage'] = av_d_g
plt.annotate(f'Average Daily Growth Percentage:{av_d_g:.3f}',xy=(20,250000))
plt.savefig('Rohani.png',dpi=900)
plt.show()

# %%
wdf = (df.iloc[
    df[df.presidency == 'Raeesi'].index[0]:-1]
      ).copy()
plt.figure(figsize=(12,4))
y = wdf.price_avg
x = np.arange(len(y))
p = curvefit(x,y)
dates = wdf.date_pr
plt.plot(x,y)
plt.xticks(x[::-365],dates[::-365])
plt.title('Raeesi')
av_d_g = wdf.price_avg.rolling(2).apply(lambda wsr: (wsr.iloc[1]-wsr.iloc[0])/wsr.iloc[0]).mean()*100
summary_df.loc['Raeesi','Average Daily Growth Percentage'] = av_d_g
plt.annotate(f'Average Daily Growth Percentage:{av_d_g:.3f}',xy=(20,450000))
plt.savefig('Raeesi.png',dpi=900)
plt.show()

# %%
import dataframe_image as dfi

# %%
summary_df
# Out:
#              Average Daily Growth Percentage
# Khamenei                             0.07742
# Rafsanjani                          0.062994
# Khatami                             0.030684
# AhmadiNezhad                        0.065124
# Rohani                              0.091848
# Raeesi                              0.135101

# %%
dfi.export(summary_df, 'summary_df.png')

# %%
summary_df.sort_values('Average Daily Growth Percentage')
# Out:
#              Average Daily Growth Percentage
# Khatami                             0.030684
# Rafsanjani                          0.062994
# AhmadiNezhad                        0.065124
# Khamenei                             0.07742
# Rohani                              0.091848
# Raeesi                              0.135101

# %%
dfi.export(summary_df.sort_values('Average Daily Growth Percentage'), 'summary_df_sorted.png')
